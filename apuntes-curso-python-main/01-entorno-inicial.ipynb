# %% [markdown]
# ## Hola mundo
# Este texto no explica nada
# $e^i - 1 = 0$

# %%
a = 20
a
# Out:
# 20

# %%
print("Hola mundo")
# Out:
# Hola mundo

# %%
print("A mimir en tu coche")
# Out:
# A mimir en tu coche

# %%
import seaborn as sns
import matplotlib.pyplot as plt

iris = sns.load_dataset("iris")

sns.scatterplot(x='sepal_length', y='petal_length', hue='species', data=iris)
plt.grid()
plt.show()

# %% [markdown]
# - item 1
# - item 2
# - item 3
